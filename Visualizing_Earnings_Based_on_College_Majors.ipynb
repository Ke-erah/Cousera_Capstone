# %% [markdown]
# <a href="https://colab.research.google.com/github/Ke-erah/Cousera_Capstone/blob/master/Visualizing_Earnings_Based_on_College_Majors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Visualizing Earnings Based on College Majors

# %% [markdown]
# We'll be working with a dataset on the job outcomes of students who graduated from college between 2010 and 2012.
#
# Each row in the dataset represents a different major in college and contains information on gender diversity, employment rates, median salaries, and more. Here are some of the columns in the dataset:
#
# 1. Rank - Rank by median earnings (the dataset is ordered by this column).
# 2. Major_code - Major code.
# 3. Major - Major description
# 4. Major_category - Category of major.
# 5. Total - Total number of people with major.
# 6. Sample_size - Sample size (unweighted) of full-time.
# 7. Men - Male graduates.
# 8. Women - Female graduates.
# 9. ShareWomen - Women as share of total.
# 10. Employed - Number employed.
# 11. Median - Median salary of full-time, year-round workers.
# 12. Low_wage_jobs - Number in low-wage service jobs.
# 13. Full_time - Number employed 35 hours or more.
# 14. Part_time - Number employed less than 35 hours

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %matplotlib inline

# %%
url = 'https://github.com/fivethirtyeight/data/raw/master/college-majors/recent-grads.csv'
recent_grads = pd.read_csv(url)

# %%
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
# Out:
#    Rank  Major_code  ... Non_college_jobs  Low_wage_jobs
# 0     1        2419  ...              364            193
# 1     2        2416  ...              257             50
# 2     3        2415  ...              176              0
# 3     4        2417  ...              102              0
# 4     5        2405  ...             4440            972
#
# [5 rows x 21 columns]

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code  ... Non_college_jobs  Low_wage_jobs
# 168   169        3609  ...             2947            743
# 169   170        5201  ...              615             82
# 170   171        5202  ...              870            622
# 171   172        5203  ...             1245            308
# 172   173        3501  ...              338            192
#
# [5 rows x 21 columns]

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code  ...  Non_college_jobs  Low_wage_jobs
# count  173.000000   173.000000  ...        173.000000     173.000000
# mean    87.000000  3879.815029  ...      13284.497110    3859.017341
# std     50.084928  1687.753140  ...      23789.655363    6944.998579
# min      1.000000  1100.000000  ...          0.000000       0.000000
# 25%     44.000000  2403.000000  ...       1591.000000     340.000000
# 50%     87.000000  3608.000000  ...       4595.000000    1231.000000
# 75%    130.000000  5503.000000  ...      11783.000000    3466.000000
# max    173.000000  6403.000000  ...     148395.000000   48207.000000
#
# [8 rows x 19 columns]

# %%
raw_data_counts = recent_grads.count()
raw_data_counts
# Out:
# Rank                    173
# Major_code              173
# Major                   173
# Total                   172
# Men                     172
# Women                   172
# Major_category          173
# ShareWomen              172
# Sample_size             173
# Employed                173
# Full_time               173
# Part_time               173
# Full_time_year_round    173
# Unemployed              173
# Unemployment_rate       173
# Median                  173
# P25th                   173
# P75th                   173
# College_jobs            173
# Non_college_jobs        173
# Low_wage_jobs           173
# dtype: int64

# %%
recent_grads = recent_grads.dropna(axis = 0)

# %%
cleaned_data_count = recent_grads.count()
cleaned_data_count
# Out:
# Rank                    172
# Major_code              172
# Major                   172
# Total                   172
# Men                     172
# Women                   172
# Major_category          172
# ShareWomen              172
# Sample_size             172
# Employed                172
# Full_time               172
# Part_time               172
# Full_time_year_round    172
# Unemployed              172
# Unemployment_rate       172
# Median                  172
# P25th                   172
# P75th                   172
# College_jobs            172
# Non_college_jobs        172
# Low_wage_jobs           172
# dtype: int64

# %% [markdown]
# # Scatter Plots

# %%
recent_grads.plot(x = 'Sample_size', y = 'Median', kind = 'scatter', title='sample size vs median salary')

# %%
recent_grads.plot(x = 'Sample_size', y = 'Unemployment_rate', kind = 'scatter', title = 'sample size vs unemployment rate')

# %%
recent_grads.plot(x = 'Full_time', y = 'Median', kind = 'scatter', title = 'full time vs median salary')

# %%
recent_grads.plot(x = 'ShareWomen', y = 'Unemployment_rate', kind = 'scatter', title = 'share women vs unemployment rate')

# %%
recent_grads.plot(x = 'Men', y = 'Median', kind = 'scatter', title = 'men vs median salary')

# %%
recent_grads.plot(x = 'Women', y = 'Median', kind = 'scatter', title = 'women vs median salary')

# %% [markdown]
# The following observations can be made from the plots:
# 1. There does not appear to be any significant correlation between gender proportion in a major and median salary earned because significant increase/difference in salary can be observed even in majors with similar gender proportion
#
# 2. Similar inference can be made for full time employment and median salary earned. Because significance difference in median salary can be seen even within the same number of people in fulltime employment

# %% [markdown]
# # Histograms

# %%
recent_grads['Sample_size'].plot(kind = 'hist', bins=30, range=(0,5000), title = 'sample size')

# %%
recent_grads['Median'].plot(kind = 'hist', bins=20, range=(20000,120000), title = 'median salary')

# %%
recent_grads['Employed'].plot(kind = 'hist', bins=30, range=(0,320000), title = 'number employed')

# %%
recent_grads['Full_time'].plot(kind = 'hist', bins=20, range=(0,300000), title = 'number employed fulltime')

# %%
recent_grads['ShareWomen'].plot(kind = 'hist', bins=10, range=(0,1), title = 'proportion of women in total')

# %%
recent_grads['Unemployment_rate'].plot(kind = 'hist', bins=10, range=(0,0.2), title = 'unemployement rate')

# %%
recent_grads['Men'].plot(kind = 'hist', bins=10, range=(100,180000), title = 'Male graduates')

# %%
recent_grads['Women'].plot(kind = 'hist', bins=15, range=(0,320000), title = 'Female graduates')

# %% [markdown]
# The most common median salary ranges between 30000 and 45000 as the bulk of the salaries falls within this range.
#
# Using th 'proportion of women in total' histogram, it can be seen that about 94 majors have roportion of women higher tha 50%. Hence, it can be said that 94 majors are predominantly female. This means there are 78 majors  that are predominantly male as there are 172 majors in total

# %% [markdown]
# # Scatter Matrix Plot

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(16,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f658d6469b0>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize=(16,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f658d594978>,
# ...
#       dtype=object)

# %% [markdown]
# From the 2 x 2 matrix, no significant correlation can be seen between the sample size and median salary
#
# From the 3 x 3 matrix, in addition to the above observation, there appears to be a very weak positive correlation between unemployment rate and median salary earned and no significant correlation between unemployment rate and sample size

# %% [markdown]
# # Bar Plot

# %%
recent_grads.head(10).plot.bar( y = 'ShareWomen', legend = False, title='sharewomen for first 10 rows')

# %%
recent_grads.tail(10).plot.bar( y = 'ShareWomen', legend = False, title = 'sharewomen for last 10 rows')

# %%
recent_grads.head(10).plot.bar(y = 'Unemployment_rate', legend = False, title = 'unemployment for first 10 rows')

# %%
recent_grads.tail(10).plot.bar( y = 'Unemployment_rate', legend = False, title = 'unemployment for last 10 rows')

# %% [markdown]
# # Additional Analysis

# %%
new_df = recent_grads.groupby('Major_category')[['Men', 'Women']].sum()
new_df
# Out:
#                                           Men     Women
# Major_category
# Agriculture & Natural Resources       40357.0   35263.0
# Arts                                 134390.0  222740.0
# Biology & Life Science               184919.0  268943.0
# Business                             667852.0  634524.0
# Communications & Journalism          131921.0  260680.0
# Computers & Mathematics              208725.0   90283.0
# Education                            103526.0  455603.0
# Engineering                          408307.0  129276.0
# Health                                75517.0  387713.0
# Humanities & Liberal Arts            272846.0  440622.0
# Industrial Arts & Consumer Services  103781.0  126011.0
# Interdisciplinary                      2817.0    9479.0
# Law & Public Policy                   91129.0   87978.0
# Physical Sciences                     95390.0   90089.0
# Psychology & Social Work              98115.0  382892.0
# ...

# %%
new_df.plot.bar(figsize=(14,6), title = 'number of men and wmen in each major category')

# %% [markdown]
# There seems to be more men in major categories that have to do with numbers such as mathematics, engineering and business while more women are in the arts, education, health sciences, life sciences and social sciences categories.
#
# However, there appears to be a higher proportio of women than men in most major categories

# %%
recent_grads['Median'].plot(kind='box', title='Distribution of Median Salary')

# %% [markdown]
# There are quite a number of outliers ranging between 62000 to over 100000. Median salary is about 35000, minimum is 30000.

# %%
recent_grads['Unemployment_rate'].plot(kind='box', title='Distribution of Unemployment_rate')

# %% [markdown]
# The unemployment rate also has some outliers between 0.14 to 0.175. Median unemployment rate is 0.0

# %%
recent_grads.plot(x='Full_time', y='Median', kind = 'hexbin', gridsize = 20, title = 'full time vs median salary')

# %%
recent_grads.plot(x='Men', y='Median', kind = 'hexbin', gridsize = 20, title = 'Men vs median salary')

# %%
recent_grads.plot(x='Women', y='Median', kind = 'hexbin', gridsize = 20, title = 'Women vs median salary')
